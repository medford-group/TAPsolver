# %%
from tapsolver import *

new_reactor = reactor()

# Define the gasses

species = reactor_species()

CO = define_gas()
CO.mass = 28
CO.intensity = 1
CO.delay = 0.0
CO.noise = 0.05
species.add_gas('CO',CO)

Ar = define_gas()
Ar.mass = 40
Ar.intensity = 1
Ar.noise = 0.05
species.add_inert_gas('Ar',Ar)

s = define_adspecies()
s.concentration = 0
species.add_adspecies('CO*',s)

s = define_adspecies()
s.concentration = 100
species.add_adspecies('*',s)

mech = mechanism()

mech.elementary_processes[0] = elementary_process('CO + * <-> CO*')
mech.elementary_processes[0].forward.k = 1
mech.elementary_processes[0].backward.k = 1

for j in mech.elementary_processes:
	mech.elementary_processes[j].forward.use = 'k'
	try:
		mech.elementary_processes[j].backward.use = 'k'
	except:
		pass

mechanism_constructor(mech)

simulation = TAPobject()
simulation.reactor = new_reactor
simulation.reactor_species = species
simulation.mechanism = mech

simulation.output_name = 'fit_new'
simulation.data_name = './exp_new/TAP_experimental_data.json'
simulation.gasses_objective = ['CO']
simulation.parameters_of_interest = ['TAPobject_data.mechanism.elementary_processes[0].forward.k','TAPobject_data.mechanism.elementary_processes[0].backward.k']
simulation.optimize = True

forward_problem(0.5,1,simulation)
flux_graph(simulation)
# Out:
# Warning: Catalyst zone will be refined and rounded to the nearest whole mesh point!
#
# New Catalyst Fraction = 0.01
# Old Catalyst Fraction = 0.009900990099009875
# Change = 1.0%
#
# Pulse #: 0
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Percent: [------------------->] 99.8%Completed in: 12.319 seconds
# test 2
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Step Time: 1659104018.443528
# Objective Value: 58362.27775125357
# Derivative Values [-30204.677694043345, 4637.26369049226]
# Parameter Values: [1.0, 1.0]
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.83623D+04    |proj g|=  3.02047D+04
# Step Time: 1659104041.4122727
# Objective Value: 36155.00862269048
# Derivative Values [-16098.540356328123, 4959.272457474361]
# Parameter Values: [1.9999999994519482, 0.9999668925452679]
#
# At iterate    1    f=  3.61550D+04    |proj g|=  1.60985D+04
# Step Time: 1659104065.054688
# Objective Value: 20822.16248029736
# Derivative Values [-8468.718624394991, 4122.689030102091]
# Parameter Values: [3.149871867488666, 0.6225052599116089]
#
# At iterate    2    f=  2.08222D+04    |proj g|=  8.46872D+03
# Step Time: 1659104088.069443
# Objective Value: 10759.350239380925
# Derivative Values [-4147.582889829375, 2636.9630405699004]
# Parameter Values: [4.465108827528299, 0.0]
#
# At iterate    3    f=  1.07594D+04    |proj g|=  4.14758D+03
# Step Time: 1659104111.833032
# Objective Value: 6926.219760509906
# Derivative Values [-2491.604000375716, 1919.002778679708]
# Parameter Values: [5.650246386741926, 0.0]
#
# At iterate    4    f=  6.92622D+03    |proj g|=  2.49160D+03
# Step Time: 1659104135.0539403
# Objective Value: 3726.922531962356
# Derivative Values [-1260.2015014234553, 1196.241417337928]
# Parameter Values: [7.433417357300857, 0.0]
#
# At iterate    5    f=  3.72692D+03    |proj g|=  1.26020D+03
# Step Time: 1659104159.8652072
# Objective Value: 2029.3299742817953
# Derivative Values [-669.5448373155926, 735.917961649373]
# Parameter Values: [9.258291625710333, 0.0]
#
# At iterate    6    f=  2.02933D+03    |proj g|=  6.69545D+02
# Step Time: 1659104185.036227
# Objective Value: 1025.988878748079
# Derivative Values [-339.2080957001315, 409.8407779337917]
# Parameter Values: [11.326896315050712, 0.0]
#
# At iterate    7    f=  1.02599D+03    |proj g|=  3.39208D+02
# Step Time: 1659104208.526631
# Objective Value: 507.4608007616272
# Derivative Values [-167.59790160108528, 199.8415390901033]
# Parameter Values: [13.45105439082523, 0.0]
#
# At iterate    8    f=  5.07461D+02    |proj g|=  1.67598D+02
# Step Time: 1659104236.353099
# Objective Value: 262.1120644121342
# Derivative Values [-77.73547580872673, 66.78879596041207]
# Parameter Values: [15.525549079429435, 0.0]
#
# At iterate    9    f=  2.62112D+02    |proj g|=  7.77355D+01
# Step Time: 1659104263.055895
# Objective Value: 166.4987944405093
# Derivative Values [-32.47500878752256, -12.227941802000972]
# Parameter Values: [17.32009034914686, 0.0]
#
# At iterate   10    f=  1.66499D+02    |proj g|=  3.24750D+01
# Step Time: 1659104292.1966286
# Objective Value: 133.56229515736248
# Derivative Values [-15.521462476090257, 72.37035860870287]
# Parameter Values: [19.501069475773654, 0.5117193075286873]
#
# At iterate   11    f=  1.33562D+02    |proj g|=  1.55215D+01
# Step Time: 1659104319.2156813
# Objective Value: 121.41791414492226
# Derivative Values [-0.2985478362568933, -5.16739548148046]
# Parameter Values: [20.267929170823866, 0.32043513995538897]
#
# At iterate   12    f=  1.21418D+02    |proj g|=  5.16740D+00
# Step Time: 1659104344.3846571
# Objective Value: 121.3305629426623
# Derivative Values [-0.23899415356354226, -0.6663267464060966]
# Parameter Values: [20.33801200398323, 0.3439896218830631]
#
# At iterate   13    f=  1.21331D+02    |proj g|=  6.66327D-01
# Step Time: 1659104371.8304598
# Objective Value: 121.32339076832486
# Derivative Values [-0.04318702217425559, 0.10549719677198031]
# Parameter Values: [20.375579291933203, 0.35070071654260593]
#
# At iterate   14    f=  1.21323D+02    |proj g|=  1.05497D-01
# Step Time: 1659104397.2089748
# Objective Value: 121.32330021809139
# Derivative Values [-0.0041802724145812865, 0.022573433347500546]
# Parameter Values: [20.3797474293169, 0.35082803391906353]
#
# At iterate   15    f=  1.21323D+02    |proj g|=  2.25734D-02
# Step Time: 1659104422.8158472
# Objective Value: 121.32329905224428
# Derivative Values [-3.044995300089457e-05, 0.0009385245378611438]
# Parameter Values: [20.380009299998193, 0.3507757541490677]
#
# At iterate   16    f=  1.21323D+02    |proj g|=  9.38525D-04
# Step Time: 1659104448.2224443
# Objective Value: 121.32329905032817
# Derivative Values [3.090227900211462e-06, 1.54769463315305e-05]
# Parameter Values: [20.380000798732347, 0.3507714870388275]
#
# At iterate   17    f=  1.21323D+02    |proj g|=  1.54769D-05
# Step Time: 1659104477.038027
# Objective Value: 121.32329905032648
# Derivative Values [6.423753751457906e-08, -1.2802340550364242e-07]
# Parameter Values: [20.380000162424086, 0.3507713639091174]
#
# At iterate   18    f=  1.21323D+02    |proj g|=  1.28023D-07
# Step Time: 1659104505.7010148
# Objective Value: 121.32329905032631
# Derivative Values [4.3895230471532636e-10, -2.2691650819600875e-09]
# Parameter Values: [20.38000015546223, 0.3507713636499089]
#
# At iterate   19    f=  1.21323D+02    |proj g|=  2.26917D-09
# Step Time: 1659104532.9584136
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
#
# At iterate   20    f=  1.21323D+02    |proj g|=  6.14317D-12
# Step Time: 1659104559.0753717
# Objective Value: 121.32329905032648
# Derivative Values [-1.6462606436565034e-13, -9.028110632749838e-14]
# Parameter Values: [20.380000155434224, 0.3507713636553368]
# Step Time: 1659104584.8736715
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659104611.1046836
# Objective Value: 121.32329905032634
# Derivative Values [4.1759591537961304e-14, -3.099287968449027e-12]
# Parameter Values: [20.380000155434214, 0.35077136365532435]
# Step Time: 1659104638.1167045
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659104664.3030121
# Objective Value: 121.32329905032638
# Derivative Values [1.3628235613935545e-13, -4.606951208840771e-12]
# Parameter Values: [20.380000155434207, 0.3507713636553181]
# Step Time: 1659104689.271118
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659104713.5945842
# Objective Value: 121.32329905032637
# Derivative Values [2.3715741688948233e-13, -5.471906953584494e-12]
# Parameter Values: [20.380000155434203, 0.35077136365531497]
# Step Time: 1659104738.132834
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659104762.5407834
# Objective Value: 121.32329905032631
# Derivative Values [2.330612843462873e-13, -5.811892165070853e-12]
# Parameter Values: [20.3800001554342, 0.3507713636553134]
# Step Time: 1659104786.3162422
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659104810.4175968
# Objective Value: 121.32329905032637
# Derivative Values [2.5252399338456025e-13, -5.979834545150133e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531264]
# Step Time: 1659104834.571867
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659104858.261523
# Objective Value: 121.3232990503264
# Derivative Values [2.5701838330314854e-13, -6.061966213689534e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531225]
# Step Time: 1659104882.466815
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# Step Time: 1659104906.553153
# Objective Value: 121.32329905032647
# Derivative Values [-1.7567789643645945e-10, 1.6753326990385846e-09]
# Parameter Values: [20.38000015543394, 0.35077136366145506]
# Step Time: 1659104932.1016624
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659104956.9705923
# Objective Value: 121.32329905032645
# Derivative Values [-8.768927430749381e-11, 8.344816786850763e-10]
# Parameter Values: [20.380000155434068, 0.35077136365838346]
# Step Time: 1659104980.9207444
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659105006.0028398
# Objective Value: 121.32329905032647
# Derivative Values [-4.372955760512767e-11, 4.1423234402646966e-10]
# Parameter Values: [20.380000155434136, 0.3507713636568477]
# Step Time: 1659105031.2638333
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659105055.3909392
# Objective Value: 121.32329905032641
# Derivative Values [-2.1707507230944995e-11, 2.0390649243576773e-10]
# Parameter Values: [20.380000155434168, 0.35077136365607975]
# Step Time: 1659105080.66544
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659105105.3975263
# Objective Value: 121.32329905032645
# Derivative Values [-1.0753443522815162e-11, 9.901974999134174e-11]
# Parameter Values: [20.380000155434182, 0.35077136365569583]
# Step Time: 1659105132.0988882
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659105159.0258834
# Objective Value: 121.32329905032641
# Derivative Values [-5.233700168593474e-12, 4.6367169252472414e-11]
# Parameter Values: [20.380000155434193, 0.3507713636555038]
# Step Time: 1659105183.224186
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
# Step Time: 1659105207.9503624
# Objective Value: 121.32329905032638
# Derivative Values [-2.4532016454103228e-12, 2.0008072868663765e-11]
# Parameter Values: [20.380000155434196, 0.35077136365540784]
# Step Time: 1659105232.8934233
# Objective Value: 121.3232990503263
# Derivative Values [2.60433585801934e-13, -6.143170413149416e-12]
# Parameter Values: [20.3800001554342, 0.35077136365531186]
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# /home/ayonge3/anaconda3/envs/tapsolver-2024/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3405: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
#     2     21     61     24     0     0   6.143D-12   1.213D+02
#   F =   121.32329905032630
#
# ABNORMAL_TERMINATION_IN_LNSRCH
